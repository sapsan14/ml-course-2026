# %% [markdown]
# # EX - Регрессия Auto MPG
#
# Этот шаблон предоставляет разделы и места, куда нужно добавить свой анализ и выводы. Заполни каждый раздел своим кодом и опиши в текстовых блоках, почему ты выбрал именно эти шаги.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

# %% [markdown]
# ## 1. Загрузка данных
#
# Загрузи файл `auto-mpg.data`. Объясни в тексте, какие признаки наиболее важны и почему `mpg` является целевой переменной.

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower',
                'weight', 'acceleration', 'model_year', 'origin', 'car_name']

if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    path = '/content/drive/MyDrive/google_colab/auto-mpg.data'
else:
    path = 'auto-mpg.data'

raw_data = pd.read_csv(path, sep='\s+', names=column_names, na_values='?')
raw_data.head()

# %% [markdown]
# Опиши основные статистические показатели в этом разделе (например, средние значения, квартили).

# %%
raw_data.describe(include='all')

# %% [markdown]
# ## 2. Предобработка данных
#
# Объясни, как ты работаешь с пропущенными значениями, некорректными данными (`?`, `n/a`, `-`) и дублирующимися строками. Опиши свой выбор в тексте и реализуй его в следующем блоке кода.

# %%
data_clean = raw_data.copy()
# TODO: преобразуй нужные столбцы в числовой тип (pd.to_numeric(..., errors='coerce'))
# TODO: выбери стратегию обработки пропущенных значений и удаления дубликатов
# data_clean = ...

data_clean

# %% [markdown]
# Опиши, почему ты удаляешь `car_name` или как преобразуешь категориальные признаки.

# %%
clean_numeric = None  # TODO: оставь только числовые / используемые в модели признаки
clean_numeric

# %% [markdown]
# ## 3. Исследование и выбор признаков
#
# Визуализируй зависимости и обоснуй, почему тот или иной признак был включён или исключён.

# %%
# TODO: создай хотя бы одну визуализацию (например, корреляционную матрицу, pairplot или диаграммы рассеяния)

# %%
selected_features = []  # TODO: добавь названия выбранных признаков
selected_features

# %% [markdown]
# ## 4. Обучающая и тестовая выборки
#
# Раздели набор данных и обоснуй выбор случайного зерна (random seed) и размера тестовой выборки.

# %%
X = None  # TODO: используй clean_numeric[selected_features]
y = None  # TODO: используй clean_numeric[target]

X_train = None
X_test = None
y_train = None
y_test = None

# TODO: используй train_test_split и сохрани результаты в переменные выше

# %% [markdown]
# ## 5. Масштабирование данных
#
# Масштабирование данных выдели в отдельный шаг: выбери подходящий scaler (например, MinMaxScaler или StandardScaler) и примени его к обучающим и тестовым данным. При необходимости масштабируй также целевую переменную.

# %%
feature_scaler = None  # TODO: выбери метод масштабирования признаков
target_scaler = None  # TODO: выбери метод масштабирования целевой переменной или оставь None, если не используешь

# TODO: масштабируй X_train и X_test (например, pd.DataFrame(feature_scaler.fit_transform(...)))
# X_train = ...
# X_test = ...

# TODO: масштабируй y_train и y_test (например, pd.Series(target_scaler.fit_transform(...)))
# y_train = ...
# y_test = ...

# TODO: при желании собери масштабированные X и y, например, с помощью pd.concat([...])
# X = ...
# y = ...

# %% [markdown]
# ## 6. Обучение моделей
#
# Обучи как минимум две модели (например, LinearRegression, Lasso, Ridge или другой метод регрессии). Добавь комментарии, почему эти варианты подходят.

# %%
model_1 = None  # TODO: создай первую модель
model_2 = None  # TODO: создай вторую модель

# TODO: обучи модели на данных X_train / y_train

# %% [markdown]
# ## 7. Оценка моделей
#
# Вычисли как минимум RMSE и R^2 для обеих моделей и составь отсортированный список `models = [(model, RMSE)]`.

# %%
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

rmse_1 = None  # TODO: вычисли RMSE первой модели
rmse_2 = None  # TODO: вычисли RMSE второй модели

r2_1 = None  # TODO: вычисли R^2 первой модели
r2_2 = None  # TODO: вычисли R^2 второй модели

models = []  # TODO: добавь пары (модель, RMSE) и отсортируй по возрастанию RMSE
models

# %% [markdown]
# ## 8. Заключение
#
# Напиши обзор из 8–20 предложений: что ты заметил, какие признаки больше всего влияют на MPG и какая модель оказалась лучшей.

# %% [markdown]
# Напиши своё заключение здесь.
