# %% [markdown]
# <a href="https://colab.research.google.com/github/sapsan14/ml-course-2026/blob/main/ex2/EX02_lahendus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - Esimesed 9 on väited, mis tuleb kinnitada või ümber lükata
#   - iga küsimuse juures tuleb vastus lisada tekstina vastava küsimuse muutujasse
#   - näiteks 1. küsumuse vastus tuleb lisada muutujasse `answer_one = "põhjendus ..."`
#   - näiteks 3. küsimuse vastus tuleb lisada muutujasse `answer_three = "põhjendus ..."`
#   - Viimased kaks küsimust vastavalt
#     - `answer_general_one = "põhjendus ..."`
#     - `answer_general_two = "põhjendus ..."`
#
#
#
# Põhjenduses (va üldised küsimused) märkida ära:
# 1. Diagrammi tüüp ning miks just see tüüp?
# 2. Vastus väitele. Kuidas diagramm toetab seda vastust.

# %% [markdown]
# # Impordime andmeseti "tips"
#
# Andmestik **`tips`** on väike ja tuntud näidisandmestik, mida kasutatakse laialdaselt andmeanalüüsi ja visualiseerimise õppimiseks. See kirjeldab restorani klientide arveid ja jäetud jootrahasid ning on kättesaadav Seaborn’i teegis käsu `sns.load_dataset("tips")` kaudu.
#
# Andmestik sisaldab **244 vaatlust** (kirjet), kus iga kirje esindab ühte restoranikülastust. Iga vaatluse kohta on talletatud nii arvulised kui ka kategoorilised tunnused, mis võimaldavad mitmekülgset statistilist analüüsi.
#
# ### Tunnused andmestikus
#
# * **`total_bill`** – arve kogusumma dollarites
# * **`tip`** – jäetud jootraha dollarites
# * **`sex`** – arve maksja sugu (Male, Female)
# * **`smoker`** – kas klient on suitsetaja (Yes, No)
# * **`day`** – nädalapäev (Thur, Fri, Sat, Sun)
# * **`time`** – söögiaeg (Lunch, Dinner)
# * **`size`** – inimeste arv lauas
#
# ### Kasutusvõimalused
#
# Andmestikku kasutatakse sageli:
#
# * jootraha ja arve summa seose analüüsimiseks
# * kliendikäitumise mustrite uurimiseks
# * erinevate gruppide (nt sugu, suitsetamine, nädalapäev) võrdlemiseks
# * visualiseerimiste ja analüüsimeetodite õppimiseks

# %%
df = sns.load_dataset("tips")
print(df.head())
print(df.tail())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# #Tee esmane analüüs andmetele

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Tõesta või lükka ümber: kasuta sobivat graafikut tõestusena

# %% [markdown]
# ## 1\. Meeste arved on naiste omadest suuremad

# %%
sns.barplot(data=df, x="sex", y="total_bill")
plt.title("Keskmine arve suurus soo lõikes")
plt.xlabel("Sugu")
plt.ylabel("Keskmine arve suurus")
plt.show()

# vastus:
# võrreldakse kahte kategooriat (mehed vs naised)
# huvi on keskmisel väärtusel, mitte üksikjuhtudel
# tulpdiagramm annab selge visuaalse vastuse väitele
# jah, meeste keskmine arve suurus on suurem kui naistel ületades 20 dollari, mil naiste keskmine arve jääv alla 20 dollari.

answer_one = "põhjendus ..."

# %% [markdown]
# ## 2\. Naised jätavad keskmiselt rohkem tippi kui mehed

# %%
sns.barplot(data=df, x="sex", y="tip")
plt.title("Keskmine jootraha soo lõikes")
plt.ylabel("Keskmine jootraha")
plt.xlabel("Sugu")
plt.show()

# vastus:
# võrreldakse kahte kategooriat (mehed vs naised)
# huvi on keskmisel jootraha suurusel, mitte üksikjuhtudel
# tulpdiagramm annab selge visuaalse vastuse väitele
# jah, meeste keskmine jäetud jootraha on suurem kui naistel

answer_two = "põhjendus ..."

# %% [markdown]
# ## 3\. Kas suitsetajate ja mittesuitsetajate jootraha varieeruvus ja mediaan erinevad?

# %%
sns.boxplot(data=df, x="smoker", y="tip")
plt.title("Jootraha jaotus: suitsetajad vs mittesuitsetajad")
plt.xlabel("Suitsetaja")
plt.ylabel("Jootraha")
plt.show()

# vastus:
# boxploti põhjal saab võrrelda suitsetajate ja mittesuitsetajate jootraha mediaani ja varieeruvust
# mediaanid on gruppide lõikes erinevad (suitsetajatel on mediaan veidi kõrgem)
# samuti on suitsetajate jootraha jaotus laiem, mis viitab suuremale varieeruvusele
# mittesuitsetajate jootraha on ühtlasem ja väiksema hajuvusega
# seega võib järeldada, et nii mediaan kui ka varieeruvus erinevad suitsetajate ja mittesuitsetajate vahel

answer_three = "põhjendus ..."

# %% [markdown]
# ## 4\. Laupäeval on kõige rohkem külastajaid

# %%
sns.countplot(data=df, x="day")
plt.title("Külastajate arv nädalapäevade lõikes")
plt.xlabel("Nädalapäev")
plt.ylabel("Külastajate arv")
plt.show()

# vastus:
# võrreldakse külastuste arvu nädalapäevade lõikes
# huvi on vaatluste (külastajate) arvul, mitte keskmisel väärtusel
# seetõttu on sobiv kasutada tulpdiagrammi külastuste arvuga (countplot)
# diagramm annab selge visuaalse vastuse, millisel päeval on kõige rohkem külastajaid
# jah, laupäeval on kõige rohkem külastajaid võrreldes teiste nädalapäevadega

answer_four = "põhjendus ..."

# %% [markdown]
# ## 5\. Millised seosed eksisteerivad arve suuruse, jootraha ja seltskonna suuruse vahel?

# %%
# valime arvulised tunnused
numeric_df = df[["total_bill", "tip", "size"]]

# arvutame korrelatsioonimaatriksi
corr = numeric_df.corr()

# joonistame korrelatsiooni heatmapi
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Korrelatsioon arve, jootraha ja seltskonna suuruse vahel")
plt.show()

# vastus:
# küsimus keskendub mitme arvulise tunnuse omavahelistele seostele
# seoste tugevuse ja suuna hindamiseks on sobiv kasutada korrelatsiooni heatmapi
# heatmap võimaldab võrrelda arve suuruse, jootraha ja seltskonna suuruse vahelisi seoseid
# tulemuste põhjal on arve suuruse ja jootraha vahel tugev positiivne korrelatsioon
# seltskonna suuruse ja arve suuruse vahel esineb mõõdukas positiivne korrelatsioon
# seltskonna suuruse ja jootraha vaheline seos on nõrk


answer_five = "põhjendus ..."

# %% [markdown]
# ## 6\. Keskmine jootraha väheneb nädala kulgedes

# %%
# määrame nädalapäevade loogilise järjekorra
day_order = ["Thur", "Fri", "Sat", "Sun"]
df["day"] = pd.Categorical(df["day"], categories=day_order, ordered=True)

sns.lineplot(
    data=df,
    x="day",
    y="tip",
    estimator="mean",
    marker="o"
)

plt.title("Keskmise jootraha muutus nädala kulgedes")
plt.xlabel("Nädalapäev")
plt.ylabel("Keskmine jootraha")
plt.show()

# vastus:
# joondiagramm näitab keskmise jootraha muutust nädalapäevade lõikes
# päevad on esitatud ajalises järjekorras
# diagrammist on näha, et keskmine jootraha ei vähene nädala kulgedes
# vastupidi, jootraha suureneb nädalalõpu poole liikudes
# seega esialgne väide ei leia kinnitust

answer_six = "põhjendus ..."

# %% [markdown]
# ## 7\. Suurem arve tähendab alati suuremat jootraha

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
plt.title("Seos arve suuruse ja jootraha vahel")
plt.xlabel("Arve suurus")
plt.ylabel("Jootraha")
plt.show()

# vastus:
# väide käsitleb kahe arvulise tunnuse (arve suurus ja jootraha) vahelist seost
# eesmärk on hinnata, kas suurem arve toob alati kaasa suurema jootraha
# sellise seose analüüsimiseks on sobiv kasutada hajuvusdiagrammi (scatterplot),
# kuna see näitab üksikvaatluste paiknemist ja võimalikke erandeid
# scatterplotist on näha, et kuigi üldine trend on tõusev,
# ei kehti väide "alati" – leidub mitmeid juhtumeid,
# kus suurema arvega on jäetud väiksem jootraha kui väiksema arve puhul
# seega on väide ümber lükatud

answer_seven = "põhjendus ..."

# %% [markdown]
# ## 8\. Enamik jootrahadest jääb väikese summa vahemikku.

# %%
sns.histplot(data=df, x="tip", bins=20)
plt.title("Jootraha jaotus")
plt.xlabel("Jootraha suurus")
plt.ylabel("Sagedus")
plt.show()

# vastus:
# histogramm kujutab jootraha jaotust ning näitab väärtuste sagedust vahemike kaupa
# diagrammist on näha, et kõige rohkem vaatlusi koondub väikeste jootrahade juurde
# suurem osa jootrahadest jääb ligikaudu vahemikku 1–3 dollarit
# suuremate jootrahade (nt üle 5 dollari) esinemissagedus on märgatavalt väiksem
# seega diagramm kinnitab väidet, et enamik jootrahadest jääb väikese summa vahemikku

answer_eight = "põhjendus ..."

# %% [markdown]
# ## 9\. Enamus ajast jäetakse tippi umbes 4 dollarit

# %%
sns.histplot(data=df, x="tip", bins=4, kde=True)
plt.title("Distribution of Tip Amounts")
plt.xlabel("Tip ($)")
plt.ylabel("Count")
plt.show()

# vastus:
# histogramm kujutab jootraha jaotust vahemike kaupa
# diagrammist on näha, et jootrahad koonduvad peamiselt vahemikku umbes 2–3 dollarit
# kuigi 4 dollari ümbruses esineb samuti jootrahade väärtusi,
# ei ole see jaotuse kõige sagedasem piirkond
# KDE-kõver kinnitab, et jaotuse tipp (mood) jääb pigem alla 4 dollari
# seega väide „Enamus ajast jäetakse tippi umbes 4 dollarit“ ei leia kinnitust
# korrektsem oleks väita, et enamik jootrahadest jääb vahemikku umbes 2–3 dollarit

answer_nine = "põhjendus ..."

# %% [markdown]
# # Üldised küsimused

# %% [markdown]
# ## 1\. Mida oskad öelda erinevate klasside võrdsuse kohta? Võta näiteks sugu ja suitsetajad/ mittesuitsetajad.

# %%
# loome ühe joonise kahe alamgraafikuga
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# sugu
sns.countplot(data=df, x="sex", ax=axes[0])
axes[0].set_title("Vaatluste arv soo lõikes")
axes[0].set_xlabel("Sugu")
axes[0].set_ylabel("Vaatluste arv")

# suitsetajad vs mittesuitsetajad
sns.countplot(data=df, x="smoker", ax=axes[1])
axes[1].set_title("Vaatluste arv suitsetamise staatuse lõikes")
axes[1].set_xlabel("Suitsetaja")
axes[1].set_ylabel("Vaatluste arv")

plt.tight_layout()
plt.show()

# vastus:
# küsimus keskendub sellele, kas erinevad klassid on andmestikus
# ligikaudu võrdselt esindatud
# huvi on vaatluste arvul kategooriate lõikes, mitte keskmistel väärtustel
# countplot on sobiv diagrammitüüp, kuna see näitab klasside sagedust
# ning võimaldab hinnata, kas andmestik on tasakaalus või kallutatud

answer_general_one = "põhjendus"

# %%
sns.countplot(data=df, x='smoker')
plt.title("Class Distribution: Smoker")
plt.show()

# %% [markdown]
# ## 2\. Mida oskad öelda tunnuste korrelatsiooni kohta?

# %%
numeric_cols = df.select_dtypes(include=["float", "int"]).columns

plt.figure(figsize=(8, 5))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numeric Variables")
plt.show()

# vastus:
# korrelatsiooni heatmap kujutab arvuliste tunnuste omavaheliste seoste tugevust ja suunda
# diagrammist on näha, et arve suuruse (total_bill) ja jootraha (tip) vahel on
# tugev positiivne korrelatsioon, mis tähendab, et suurema arve korral jäetakse
# üldiselt rohkem jootraha
# seltskonna suuruse (size) ja arve suuruse vahel esineb mõõdukas positiivne korrelatsioon,
# mis viitab sellele, et suuremad seltskonnad teevad tavaliselt suuremaid tellimusi
# seltskonna suuruse ja jootraha vaheline korrelatsioon on nõrk,
# mis tähendab, et inimeste arv lauas ei mõjuta jootraha suurust otseselt
# negatiivseid tugevaid korrelatsioone tunnuste vahel ei esine
# seega on kõige tugevam seos arve suuruse ja jootraha vahel

answer_general_two = "põhjendus"

# %% [markdown]
# ## 3\. Kas jootraha suurus sisaldab erindeid ja kuidas need erinevad nädalapäevade lõikes?

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(
    data=df,
    x="day",
    y="tip",
    showfliers=True
)

plt.title("Jootraha suurus ja erindid nädalapäevade lõikes")
plt.xlabel("Nädalapäev")
plt.ylabel("Jootraha ($)")
plt.show()

# vastus:
# joonisel kujutatud boxplot näitab, et jootraha suuruse andmetes
# esineb erindväärtusi ainult osadel nädalapäevadel
# konkreetselt on erindväärtused nähtavad neljapäeval (Thur) ja laupäeval (Sat)
# reedese (Fri) ja pühapäevase (Sun) jootraha jaotuse puhul
# erindväärtusi joonisel ei esine
# see tähendab, et väga suuri jootrahade väärtusi esineb vaid
# teatud nädalapäevadel, mitte kogu nädala lõikes

answer_general_three = "põhjendus"
