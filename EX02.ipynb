# %% [markdown]
# <a href="https://colab.research.google.com/github/sapsan14/ml-course-2026/blob/main/EX02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - **Ülesande Notebook'i nimi peab olema 'EX02.ipynb'**
# - **See Notebook on *readonly* õigustes, tee sellest endale koopia File --> Save a copy in Drive**

# %%
"""EX02."""
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# - Esimesed 9 on väited, mis tuleb kinnitada või ümber lükata
#   - iga küsimuse juures tuleb vastus lisada tekstina vastava küsimuse juuurdekäiva muutuja sisse
#   - Vastus peab algama väite kinnitamise või ümberlükkamisega st. vastus algab sõnaga "Ei" või "Jah"
#   - näiteks 1. küsimuse vastus tuleb lisada muutujasse `answer_one = "Jah, sest ..."`
#   - näiteks 3. küsimuse vastus tuleb lisada muutujasse `answer_three = "Ei, sest ..."`
#   - Viimased kolm küsimust vastavalt
#     - `answer_general_one = "põhjendus ..."`
#     - `answer_general_two = "põhjendus ..."`
#     - `answer_general_three = "põhjendus ..."`

# %% [markdown]
# # Impordime andmeseti "tips"
#
# Andmestik **`tips`** on väike ja tuntud näidisandmestik, mida kasutatakse laialdaselt andmeanalüüsi ja visualiseerimise õppimiseks. See kirjeldab restorani klientide arveid ja jäetud jootrahasid ning on kättesaadav Seaborn’i teegis käsu `sns.load_dataset("tips")` kaudu.
#
# Andmestik sisaldab **244 vaatlust** (kirjet), kus iga kirje esindab ühte restoranikülastust. Iga vaatluse kohta on talletatud nii arvulised kui ka kategoorilised tunnused, mis võimaldavad mitmekülgset statistilist analüüsi.
#
# ### Tunnused andmestikus
#
# * **`total_bill`** – arve kogusumma dollarites
# * **`tip`** – jäetud jootraha dollarites
# * **`sex`** – arve maksja sugu (Male, Female)
# * **`smoker`** – kas klient on suitsetaja (Yes, No)
# * **`day`** – nädalapäev (Thur, Fri, Sat, Sun)
# * **`time`** – söögiaeg (Lunch, Dinner)
# * **`size`** – inimeste arv lauas
#
# ### Kasutusvõimalused
#
# Andmestikku kasutatakse sageli:
#
# * jootraha ja arve summa seose analüüsimiseks
# * kliendikäitumise mustrite uurimiseks
# * erinevate gruppide (nt sugu, suitsetamine, nädalapäev) võrdlemiseks
# * visualiseerimiste ja analüüsimeetodite õppimiseks

# %%
if "google.colab" in sys.modules:
    df = sns.load_dataset("tips")
else:
    df = pd.read_csv("tips.csv")

print(df.head())
print(df.tail())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# #Tee esmane analüüs andmetele

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Tõesta või lükka ümber: kasuta sobivat graafikut tõestusena

# %% [markdown]
# ## 1\. Meeste arved on naiste omadest suuremad

# %%
# Väide: Meeste keskmine arve suurus on suurem kui naistel
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_one = "Ei, sest ..." või  answer_one = "Jah, sest ..."
answer_one = "..., sest ..."

# %% [markdown]
# ## 2\. Naised jätavad keskmiselt rohkem jootraha kui mehed

# %%
# Väide: Naised jätavad keskmiselt rohkem jootraha kui mehed
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_two = "Ei, sest ..." või answer_two = "Jah, sest ..."
answer_two = "..., sest ..."

# %% [markdown]
# ## 3\. Kas suitsetajate ja mittesuitsetajate jootraha varieeruvus ja mediaan erinevad?

# %%
# Vata: Kas suitsetajate ja mittesuitsetajate jootraha varieeruvus ja mediaan erinevad?
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_three = "Ei, sest ..." või answer_three = "Jah, sest ..."
answer_three = "..., sest ..."

# %% [markdown]
# ## 4\. Laupäeval on kõige rohkem külastajaid

# %%
# Väide: Laupäeval on kõige rohkem külastajaid
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_four = "Ei, sest ..." või answer_four = "Jah, sest ..."
answer_four = "..., sest ..."

# %% [markdown]
# ## 5\. Arve suuruse ja jootraha vahel on tugev positiivne korrelatsioon

# %%
# Väide: Arve suuruse ja jootraha vahel on tugev positiivne korrelatsioon
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_five = "Ei, sest ..." või answer_five = "Jah, sest ..."
answer_five = "..., sest ..."

# %% [markdown]
# ## 6\. Keskmine jootraha väheneb nädala kulgedes

# %%
# Väide: Keskmine jootraha väheneb nädala kulgedes
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_six = "Ei, sest ..." või answer_six = "Jah, sest ..."
answer_six = "..., sest ..."

# %% [markdown]
# ## 7\. Suurem arve tähendab alati suuremat jootraha

# %%
# Väide: Suurem arve tähendab alati suuremat jootraha
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_seven = "Ei, sest ..." või answer_seven = "Jah, sest ..."
answer_seven = "..., sest ..."

# %% [markdown]
# ## 8\. Enamik jootrahadest on väiksem kui 5 dollarit

# %%
# Väide: Enamik jootrahadest on väiksem kui 5 dollarit
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_eight = "Ei, sest ..." või answer_eight = "Jah, sest ..."
answer_eight = "..., sest ..."

# %% [markdown]
# ## 9\. Enamus ajast jäetakse jootraha umbes 4 dollarit

# %%
# Väide: Enamus ajast jäetakse jootraha umbes 4 dollarit
# Joonista sobiv graafik ja vaata graafikult, kas väide peab paika


# Alusta vastust väite kinnitamise või ümberlükkamisega
# Näiteks: answer_nine = "Ei, sest ..." või answer_nine = "Jah, sest ..."
answer_nine = "..., sest ..."

# %% [markdown]
# # Üldised küsimused

# %% [markdown]
# ## 1\. Mida oskad öelda erinevate klasside võrdsuse kohta? Võta näiteks sugu ja suitsetajad/ mittesuitsetajad.

# %%
# Joonista sobiv graafik/graafikud ja vasta paari lausega

answer_general_one = "põhjendus"

# %% [markdown]
# ## 2\. Mida oskad öelda tunnuste korrelatsiooni kohta?

# %%
# Joonista sobiv graafik/graafikud ja vasta paari lausega

answer_general_two = "põhjendus"

# %% [markdown]
# ## 3\. Kas jootraha suurus sisaldab erindeid ja kuidas need erinevad nädalapäevade lõikes?

# %%
# Joonista sobiv graafik/graafikud ja vasta paari lausega

answer_general_three = "põhjendus"
